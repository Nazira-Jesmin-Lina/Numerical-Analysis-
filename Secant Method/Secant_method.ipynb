# %%
import matplotlib.pyplot as plt
import numpy as np


def value_of_fxx(x):
    return 3*x**2-1

def value_of_fx(x):
    return x**3-x-1


print("                     Secant Method                   ")
print(" ")


iter_nmbr=[]
approximation_err=[]
rel_apprx=[]
x0=50
x1=48
i=0
x2=999999999
while abs(value_of_fx(x2))>= 10 ** -6:
    x2=(x0*value_of_fx(x1))-(x1*value_of_fx(x0))
    x2=x2/(value_of_fx(x1)-value_of_fx(x0))
    apprxmtn=abs(x2-x1)
    rel_apprxmtn=(apprxmtn*100)/x2
    print(f" Xi-1 : {x0:10.6f}  |  f(xi-1) :{value_of_fx(x0):15.6f} | f'(x-1):{value_of_fxx(x1):15.6f} |  xi+1:{x2:15.6f} | Approximation Error:{apprxmtn:15.6f} | Relative Approximation Error:{rel_apprxmtn:10.4f}%    ")
    i=i+1
    iter_nmbr.append(i)
    approximation_err.append(apprxmtn)
    rel_apprx.append(rel_apprxmtn)
    x0=x1
    x1=x2


print("")
iter_nmbr_new=[]
approximation_err_new=[]
rel_apprx_neew=[]
x=50
i=0
print("                     Newton Raphson Method                   ")
print(" ")
while abs(value_of_fx(x))>= 10 ** -6:

    xi=x-(value_of_fx(x)/value_of_fxx(x))
    apprxmtn=abs(xi-x)
    rel_apprxmtn=(apprxmtn*100)/xi
    print(f" Xi-1 : {xi:10.6f}  |  f(xi-1) :{value_of_fx(x):15.6f} | f'(x-1):{value_of_fxx(x):15.6f} |  xi+1:{xi:15.6f} | Approximation Error:{apprxmtn:15.6f} | Relative Approximation Error:{rel_apprxmtn:10.4f}%    ")
    x=xi
    i=i+1
    iter_nmbr_new.append(i)
    approximation_err_new.append(apprxmtn)
    rel_apprx_neew.append(rel_apprxmtn)


print("")
x = np.array(iter_nmbr)
y = np.array(approximation_err)

plt.bar(x,y,label="secant method")
plt.xlabel("Iteration Number")
plt.ylabel("Approximation error")
plt.title("Secant Method Approximaation error vs Iteration Number")
plt.show()

y=np.array(rel_apprx)
plt.bar(x,y,label="secant method")
plt.xlabel("Iteration Number")
plt.ylabel("Relative Approximation error")
plt.title("Secant Method Relative Approximaation error vs Iteration Number")
plt.show()

y = np.array(approximation_err)
x_new = np.array(iter_nmbr_new)
y_new = np.array(approximation_err_new)

plt.plot(x,y,label="Secant Method")
plt.plot(x_new,y_new,label="Newton Raphson")
plt.xlabel("Iteration Number")
plt.ylabel("Approximation error")
plt.title("Secant Method vs Newton Raphson Method")
plt.legend()
plt.show()

y = np.array(rel_apprx)
y_new = np.array(rel_apprx_neew)

plt.plot(x,y,label="Secant Method")
plt.plot(x_new,y_new,label="Newton Raphson")
plt.xlabel("Iteration Number")
plt.ylabel("Relative Approximation error")
plt.title("Secant Method vs Newton Raphson Method")
plt.legend()
plt.show()
# Out:
#                      Secant Method
#
#  Xi-1 :  50.000000  |  f(xi-1) :  124949.000000 | f'(x-1):    6911.000000 |  xi+1:      32.653200 | Approximation Error:      15.346800 | Relative Approximation Error:   46.9994%
#  Xi-1 :  48.000000  |  f(xi-1) :  110543.000000 | f'(x-1):    3197.694422 |  xi+1:      25.607395 | Approximation Error:       7.045805 | Relative Approximation Error:   27.5147%
#  Xi-1 :  32.653200  |  f(xi-1) :   34782.216422 | f'(x-1):    1966.216026 |  xi+1:      19.051166 | Approximation Error:       6.556229 | Relative Approximation Error:   34.4138%
#  Xi-1 :  25.607395  |  f(xi-1) :   16765.151835 | f'(x-1):    1087.840825 |  xi+1:      14.471728 | Approximation Error:       4.579439 | Relative Approximation Error:   31.6440%
#  Xi-1 :  19.051166  |  f(xi-1) :    6894.511419 | f'(x-1):     627.292712 |  xi+1:      10.912027 | Approximation Error:       3.559701 | Relative Approximation Error:   32.6218%
#  Xi-1 :  14.471728  |  f(xi-1) :    3015.355296 | f'(x-1):     356.217005 |  xi+1:       8.259868 | Approximation Error:       2.652159 | Relative Approximation Error:   32.1090%
#  Xi-1 :  10.912027  |  f(xi-1) :    1287.408517 | f'(x-1):     203.676281 |  xi+1:       6.254754 | Approximation Error:       2.005115 | Relative Approximation Error:   32.0575%
#  Xi-1 :   8.259868  |  f(xi-1) :     554.273183 | f'(x-1):     116.365835 |  xi+1:       4.752050 | Approximation Error:       1.502703 | Relative Approximation Error:   31.6222%
#  Xi-1 :   6.254754  |  f(xi-1) :     237.443381 | f'(x-1):      66.745951 |  xi+1:       3.628947 | Approximation Error:       1.123103 | Relative Approximation Error:   30.9485%
#  Xi-1 :   4.752050  |  f(xi-1) :     101.558675 | f'(x-1):      38.507773 |  xi+1:       2.798856 | Approximation Error:       0.830092 | Relative Approximation Error:   29.6583%
#  Xi-1 :   3.628947  |  f(xi-1) :      43.161593 | f'(x-1):      22.500778 |  xi+1:       2.197848 | Approximation Error:       0.601008 | Relative Approximation Error:   27.3453%
#  Xi-1 :   2.798856  |  f(xi-1) :      18.126239 | f'(x-1):      13.491607 |  xi+1:       1.781419 | Approximation Error:       0.416429 | Relative Approximation Error:   23.3763%
#  Xi-1 :   2.197848  |  f(xi-1) :       7.418935 | f'(x-1):       8.520356 |  xi+1:       1.518413 | Approximation Error:       0.263005 | Relative Approximation Error:   17.3211%
#  Xi-1 :   1.781419  |  f(xi-1) :       2.871828 | f'(x-1):       5.916736 |  xi+1:       1.381663 | Approximation Error:       0.136750 | Relative Approximation Error:    9.8975%
#  Xi-1 :   1.518413  |  f(xi-1) :       0.982408 | f'(x-1):       4.726978 |  xi+1:       1.333490 | Approximation Error:       0.048173 | Relative Approximation Error:    3.6126%
#  Xi-1 :   1.381663  |  f(xi-1) :       0.255922 | f'(x-1):       4.334584 |  xi+1:       1.325163 | Approximation Error:       0.008326 | Relative Approximation Error:    0.6283%
#  Xi-1 :   1.333490  |  f(xi-1) :       0.037714 | f'(x-1):       4.268175 |  xi+1:       1.324722 | Approximation Error:       0.000442 | Relative Approximation Error:    0.0334%
#  Xi-1 :   1.325163  |  f(xi-1) :       0.001901 | f'(x-1):       4.264662 |  xi+1:       1.324718 | Approximation Error:       0.000004 | Relative Approximation Error:    0.0003%
#
#                      Newton Raphson Method
#
#  Xi-1 :  33.337912  |  f(xi-1) :  124949.000000 | f'(x-1):    7499.000000 |  xi+1:      33.337912 | Approximation Error:      16.662088 | Relative Approximation Error:   49.9794%
#  Xi-1 :  22.232242  |  f(xi-1) :   37017.962516 | f'(x-1):    3333.249074 |  xi+1:      22.232242 | Approximation Error:      11.105669 | Relative Approximation Error:   49.9530%
#  Xi-1 :  14.832172  |  f(xi-1) :   10965.555822 | f'(x-1):    1481.817785 |  xi+1:      14.832172 | Approximation Error:       7.400070 | Relative Approximation Error:   49.8920%
#  Xi-1 :   9.904637  |  f(xi-1) :    3247.146623 | f'(x-1):     658.979971 |  xi+1:       9.904637 | Approximation Error:       4.927535 | Relative Approximation Error:   49.7498%
#  Xi-1 :   6.629014  |  f(xi-1) :     960.758503 | f'(x-1):     293.305519 |  xi+1:       6.629014 | Approximation Error:       3.275624 | Relative Approximation Error:   49.4134%
#  Xi-1 :   4.460765  |  f(xi-1) :     283.675177 | f'(x-1):     130.831464 |  xi+1:       4.460765 | Approximation Error:       2.168249 | Relative Approximation Error:   48.6071%
#  Xi-1 :   3.041546  |  f(xi-1) :      83.301414 | f'(x-1):      58.695266 |  xi+1:       3.041546 | Approximation Error:       1.419219 | Relative Approximation Error:   46.6611%
#  Xi-1 :   2.140870  |  f(xi-1) :      24.095805 | f'(x-1):      26.753008 |  xi+1:       2.140870 | Approximation Error:       0.900676 | Relative Approximation Error:   42.0706%
#  Xi-1 :   1.617619  |  f(xi-1) :       6.671427 | f'(x-1):      12.749968 |  xi+1:       1.617619 | Approximation Error:       0.523250 | Relative Approximation Error:   32.3470%
#  Xi-1 :   1.381827  |  f(xi-1) :       1.615192 | f'(x-1):       6.850075 |  xi+1:       1.381827 | Approximation Error:       0.235792 | Relative Approximation Error:   17.0638%
#  Xi-1 :   1.327538  |  f(xi-1) :       0.256699 | f'(x-1):       4.728341 |  xi+1:       1.327538 | Approximation Error:       0.054289 | Relative Approximation Error:    4.0895%
#  Xi-1 :   1.324725  |  f(xi-1) :       0.012058 | f'(x-1):       4.287071 |  xi+1:       1.324725 | Approximation Error:       0.002813 | Relative Approximation Error:    0.2123%
#  Xi-1 :   1.324718  |  f(xi-1) :       0.000031 | f'(x-1):       4.264692 |  xi+1:       1.324718 | Approximation Error:       0.000007 | Relative Approximation Error:    0.0006%
